# %%
import requests
import networkx as nx
import torch
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from github import Github
from operator import itemgetter
import sys

# %%
GITHUB_API_URL = "https://api.github.com"
GITHUB_TOKEN = "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"

headers = {
    "Authorization": f"token {GITHUB_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}
USER = 'kyleskom'
REPO = 'NBA-Machine-Learning-Sports-Betting'
client = Github(GITHUB_TOKEN, per_page=100)
user = client.get_user(USER)
repo = user.get_repo(REPO)
stargazers = [ s for s in repo.get_stargazers() ]
print("Number of stargazers", len(stargazers))

# %%
# Expand the initial graph with (interest) edges pointing each direction for 
# additional people interested. Take care to ensure that user and repo nodes 
g = nx.DiGraph()
g.add_node(repo.name + '(repo)', type='repo', lang=repo.language, owner=user.login)

for sg in stargazers:
    g.add_node(sg.login + '(user)', type='user')
    g.add_edge(sg.login + '(user)', repo.name + '(repo)', type='gazes')

# %%
for i, sg in enumerate(stargazers):
    
    # Add "follows" edges between stargazers in the graph if any relationships exist
    try:
        for follower in sg.get_followers():
            if follower.login + '(user)' in g:
                g.add_edge(follower.login + '(user)', sg.login + '(user)', 
                           type='follows')
    except Exception as e: #ssl.SSLError
        print("Encountered an error fetching followers for", sg.login, \
              "Skipping.", file=sys.stderr)
        print(e, file=sys.stderr)

    print("Processed", i+1, " stargazers. Num nodes/edges in graph", \
          g.number_of_nodes(), "/", g.number_of_edges())
    print("Rate limit remaining", client.rate_limiting)

# %%
c = Counter([e[1] for e in g.edges(data=True) if e[2]['type'] == 'follows'])
popular_users = [ (u, f) for (u, f) in c.most_common() if f > 1 ]
print("Number of popular users", len(popular_users))
print("Top 10 popular users:", popular_users[:10])
# Out:
# Number of popular users 13
# Top 10 popular users: [('llSourcell(user)', 59), ('nkgilley(user)', 9), ('eddwebster(user)', 8), ('gingfacekillah(user)', 7), ('nealmick(user)', 6), ('cryptocoinserver(user)', 2), ('markjoeljimenez(user)', 2), ('JaySCarter(user)', 2), ('robbiejdunne(user)', 2), ('ParthS28(user)', 2)]

# %%
h = g.copy()
# Remove the seed of the interest graph, which is a supernode, in order
# to get a better idea of the network dynamics
h.remove_node('NBA-Machine-Learning-Sports-Betting(repo)')
dc = sorted(nx.degree_centrality(h).items(), key=itemgetter(1), reverse=True)
print("Degree Centrality")
print(dc[:10])
print()
bc = sorted(nx.betweenness_centrality(h).items(), key=itemgetter(1), reverse=True)
print("Betweenness Centrality")
print(bc[:10])
print()
print("Closeness Centrality")
cc = sorted(nx.closeness_centrality(h).items(), key=itemgetter(1), reverse=True)
print(cc[:10])
# Out:
# Degree Centrality
# [('llSourcell(user)', 0.05427782888684453), ('eddwebster(user)', 0.010119595216191352), ('nkgilley(user)', 0.00827966881324747), ('gingfacekillah(user)', 0.006439742410303588), ('nealmick(user)', 0.005519779208831647), ('fly51fly(user)', 0.004599816007359705), ('eddwebsterlcfc(user)', 0.0036798528058877645), ('JaySCarter(user)', 0.0027598896044158236), ('robbiejdunne(user)', 0.0027598896044158236), ('ParthS28(user)', 0.0027598896044158236)]
#
# Betweenness Centrality
# [('eddwebster(user)', 1.5248008864175819e-05), ('KyleWilliamz(user)', 8.471116035653233e-07), ('Oldhuntor(user)', 8.471116035653233e-07), ('HarperGrieve(user)', 0.0), ('cryptocoinserver(user)', 0.0), ('tomdicato(user)', 0.0), ('afzongho(user)', 0.0), ('munozjoseph-sportsBI(user)', 0.0), ('bmckelvey11(user)', 0.0), ('rgl77(user)', 0.0)]
#
# Closeness Centrality
# [('llSourcell(user)', 0.05429291025080308), ('nkgilley(user)', 0.00827966881324747), ('eddwebster(user)', 0.007359705611775529), ('gingfacekillah(user)', 0.006439742410303588), ('nealmick(user)', 0.005519779208831647), ('JaySCarter(user)', 0.004205546063871731), ('robbiejdunne(user)', 0.004205546063871731), ('ParthS28(user)', 0.004205546063871731), ('cryptocoinserver(user)', 0.0018399264029438822), ('markjoeljimenez(user)', 0.0018399264029438822)]

# %%
MAX_REPOS = 50
for i, sg in enumerate(stargazers):
    print(sg.login)
    try:
        for starred in sg.get_starred()[:MAX_REPOS]: # Slice to avoid supernodes
            g.add_node(starred.name + '(repo)', type='repo', lang=starred.language, \
                       owner=starred.owner.login)
            g.add_edge(sg.login + '(user)', starred.name + '(repo)', type='gazes')
    except Exception as e: #ssl.SSLError:
        print("Encountered an error fetching starred repos for", sg.login, "Skipping.")

    print("Processed", i+1, "stargazers' starred repos")
    print("Num nodes/edges in graph", g.number_of_nodes(), "/", g.number_of_edges())
    print("Rate limit", client.rate_limiting)

# %%
# Get a list of repositories from the graph.
repos = [n for n in g.nodes() if g.nodes[n]['type'] == 'repo']
# Most popular repos
print("Popular repositories")
print(sorted([(n,d) for (n,d) in g.in_degree() if g.nodes[n]['type'] == 'repo'], key=itemgetter(1), reverse=True)[:10])
# Out:
# Popular repositories
# [('NBA-Machine-Learning-Sports-Betting(repo)', 1088), ('ChatGPT_Sports_Betting_Bot(repo)', 83), ('sports-betting(repo)', 71), ('public-apis(repo)', 60), ('AutoGPT(repo)', 56), ('NBA_Betting(repo)', 46), ('nba_api(repo)', 45), ('build-your-own-x(repo)', 44), ('ProphitBet-Soccer-Bets-Predictor(repo)', 41), ('Sports-betting(repo)', 40)]
#
# Supernode candidates
# []
# Graph has 19095 nodes
# Graph has 26777 edges

# %%
repos = [n for n in g.nodes() if g.nodes[n]['type'] == 'repo']
for repo in repos:
    lang = (g.nodes[repo]['lang'] or "") + "(lang)"
    stargazers = [u for (u, r, d) in g.in_edges(repo, data=True) if d['type'] == 'gazes']
    for sg in stargazers:
        g.add_node(lang, type='lang')
        g.add_edge(sg, lang, type='programs')
        g.add_edge(lang, repo, type='implements')

# %%
print([n for n in g.nodes() if g.nodes[n]['type'] == 'lang'])
print("Most popular languages")
print(sorted([(n, g.in_degree(n)) for n in g.nodes() if g.nodes[n]['type'] == 'lang'], key=itemgetter(1), reverse=True)[:10])
python_programmers = [u 
                      for (u, l) in g.in_edges('Python(lang)') 
                          if g.nodes[u]['type'] == 'user']
print("Number of Python programmers:", len(python_programmers))
print()
javascript_programmers = [u for 
                          (u, l) in g.in_edges('JavaScript(lang)') 
                              if g.nodes[u]['type'] == 'user']
print("Number of JavaScript programmers:", len(javascript_programmers))
print()
typescript_programmers = [u for 
                          (u, l) in g.in_edges('TypeScript(lang)') 
                              if g.nodes[u]['type'] == 'user']
print("Number of TypeScript programmers:", len(typescript_programmers))
print()
html_programmers = [u for 
                          (u, l) in g.in_edges('HTML(lang)') 
                              if g.nodes[u]['type'] == 'user']
print("Number of HTML programmers:", len(html_programmers))

print(len(set(python_programmers).intersection(set(javascript_programmers))))
print(len(set(javascript_programmers).intersection(set(html_programmers))))
print(len(set(typescript_programmers).intersection(set(html_programmers))))
# Out:
# ['Python(lang)', 'Java(lang)', 'Jupyter Notebook(lang)', 'Rust(lang)', 'C(lang)', 'TypeScript(lang)', 'C#(lang)', '(lang)', 'C++(lang)', 'R(lang)', 'JavaScript(lang)', 'SCSS(lang)', 'HTML(lang)', 'Ruby(lang)', 'MATLAB(lang)', 'SAS(lang)', 'Clojure(lang)', 'NCL(lang)', 'PHP(lang)', 'Dart(lang)', 'Lua(lang)', 'Go(lang)', 'MDX(lang)', 'Vue(lang)', 'Elixir(lang)', 'Shell(lang)', 'CSS(lang)', 'Solidity(lang)', 'VBScript(lang)', 'Objective-C(lang)', 'Swift(lang)', 'Cuda(lang)', 'Vim Script(lang)', 'TeX(lang)', 'Smarty(lang)', 'Matlab(lang)', 'Pug(lang)', 'Markdown(lang)', 'Dockerfile(lang)', 'Jinja(lang)', 'CoffeeScript(lang)', 'Brightscript(lang)', 'BrighterScript(lang)', 'Batchfile(lang)', 'Stata(lang)', 'Astro(lang)', 'Scala(lang)', 'Zig(lang)', 'Julia(lang)', 'HCL(lang)', 'Perl(lang)', 'Makefile(lang)', 'YAML(lang)', 'Sieve(lang)', 'Fortran(lang)', 'PostScript(lang)', 'PowerShell(lang)', 'Crystal(lang)', 'Svelte(lang)', 'Mojo(lang)', 'OpenEdge ABL(lang)', 'Kotlin(lang)', 'Smali(lang)', 'Stylus(lang)', 'Objective-C++(lang)', 'OCaml(lang)', 'Blade(lang)', 'PLpgSQL(lang)', 'Less(lang)', 'Meson(lang)', 'Groff(lang)', 'ASL(lang)', 'Haxe(lang)', 'Emacs Lisp(lang)', 'Visual Basic .NET(lang)', 'Nix(lang)', 'F#(lang)', 'Common Lisp(lang)', 'Haskell(lang)', 'Metal(lang)', 'EJS(lang)', 'Fluent(lang)', 'FORTRAN(lang)', 'Vyper(lang)', 'MQL5(lang)', 'Tcl(lang)', 'Org(lang)', 'VBA(lang)', 'xBase(lang)', 'Rich Text Format(lang)', 'Vim script(lang)', 'Hack(lang)', 'Scheme(lang)', 'Visual Basic(lang)', 'TSQL(lang)', 'SQLPL(lang)', 'Assembly(lang)', 'P4(lang)', 'Groovy(lang)', 'Coq(lang)', 'GAP(lang)', 'JetBrains MPS(lang)', 'ApacheConf(lang)', 'Roff(lang)', 'ZenScript(lang)', 'QML(lang)', 'Nunjucks(lang)', 'Cython(lang)', 'Verilog(lang)', 'ShaderLab(lang)', 'CMake(lang)', 'HLSL(lang)', 'GDScript(lang)', 'V(lang)', 'Mustache(lang)', 'Starlark(lang)', 'XSLT(lang)', 'JSON(lang)', 'GLSL(lang)', 'Sass(lang)', 'Nim(lang)', 'Nextflow(lang)', 'Liquid(lang)', 'OpenSCAD(lang)', 'q(lang)', 'Mathematica(lang)', 'Processing(lang)', 'SystemVerilog(lang)', 'SourcePawn(lang)', 'AutoIt(lang)', 'Twig(lang)', 'PlantUML(lang)', 'Cadence(lang)', 'Protocol Buffer(lang)', 'Gherkin(lang)', 'DIGITAL Command Language(lang)', 'Fennel(lang)', 'PLSQL(lang)', 'Max(lang)', 'Erlang(lang)', 'Awk(lang)', 'Wikitext(lang)', 'Forth(lang)', 'Pascal(lang)', 'BitBake(lang)', 'D(lang)', 'AutoHotkey(lang)', 'WebAssembly(lang)', 'ActionScript(lang)', 'Xtend(lang)', 'PureScript(lang)', 'Lean(lang)', 'Visual Basic 6.0(lang)', 'Logos(lang)', 'CodeQL(lang)', 'VimL(lang)', 'FreeMarker(lang)', 'Vala(lang)', 'G-code(lang)', 'Pawn(lang)', 'AMPL(lang)', 'Text(lang)', 'Move(lang)', 'Arduino(lang)', 'VHDL(lang)', 'HolyC(lang)', 'AppleScript(lang)', 'Elm(lang)', 'Ballerina(lang)']
#
# Most popular languages
# [('Python(lang)', 1088), ('(lang)', 642), ('Jupyter Notebook(lang)', 587), ('JavaScript(lang)', 562), ('TypeScript(lang)', 504), ('HTML(lang)', 383), ('C++(lang)', 325), ('Go(lang)', 280), ('C(lang)', 261), ('Java(lang)', 253)]
#
# Number of Python programmers: 1088
#
# Number of JavaScript programmers: 562
#
# Number of TypeScript programmers: 504
#
# Number of HTML programmers: 383
#
# Number of programmers who use JavaScript and Python
# 562
# 288
# 273
# Number of programmers who use JavaScript but not Python
# 0

# %%
UG = nx.Graph()

UG.add_nodes_from(g.nodes(data=True))

for u, v in g.edges():
    if not UG.has_edge(u, v) and not UG.has_edge(v, u):
        UG.add_edge(u, v)

communities = list(nx.algorithms.community.greedy_modularity_communities(UG))
print("\nCommunity Detection:")
for i, community in enumerate(communities):
    print(f"Community {i + 1}: {', '.join(community)}")

def analyze_degree_distribution(G, communities):
    for i, community in enumerate(communities):
        subgraph = G.subgraph(community)
        degree_distribution = sorted(subgraph.degree(), key=lambda x: x[1], reverse=True)
        top_degree_nodes = degree_distribution[:10]  
        print(f"Top 10 nodes by degree distribution in Community {i + 1}: {top_degree_nodes}")
analyze_degree_distribution(UG, communities)
def analyze_centrality(G, communities):
    for i, community in enumerate(communities):
        subgraph = G.subgraph(community)
        degree_centrality = nx.degree_centrality(subgraph)
        betweenness_centrality = nx.betweenness_centrality(subgraph)
        closeness_centrality = nx.closeness_centrality(subgraph)
        sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
        sorted_betweenness_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
        sorted_closeness_centrality = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)
        print(f"Key nodes in Community {i + 1} (sorted by degree centrality): {sorted_degree_centrality[:5]}")
        print(f"Key nodes in Community {i + 1} (sorted by betweenness centrality): {sorted_betweenness_centrality[:5]}")
        print(f"Key nodes in Community {i + 1} (sorted by closeness centrality): {sorted_closeness_centrality[:5]}")

analyze_centrality(UG, communities)
# Out:
# Community Detection:
# Community 1: FastSAM(repo), lechiman(user), PyGazeAnalyser(repo), ollama-telegram(repo), AutoPrompt(repo), matplotlib(repo), MLSTM-FCN(repo), pytorch_geometric(repo), contrastors(repo), d2l-en(repo), PPPwn(repo), Stock-News-Scrapping-With-Python(repo), TTNet-Real-time-Analysis-System-for-Table-Tennis-Pytorch(repo), Doxa(repo), age-of-empires-II-api(repo), Netclone_Netflix-UI-Clone(repo), imcp23(repo), PressScraper(repo), zdd_adventure2023(repo), article_openai_bot(repo), Transfer-Learning-Library(repo), AudioLDM2(repo), AutoMates(repo), Py-Boost(repo), bark-voice-cloning-HuBERT-quantizer(repo), DFSLineupOptimizer(repo), langchain-chatbot(repo), Auto_Track_generation_and_upload(repo), ERKER2Phenopackets(repo), dolly(repo), OpenCV-Object-Face-Tracking(repo), mTAN(repo), CS231n-2017-Summary(repo), mmpose(repo), ijepa(repo), griptape(repo), Modmail(repo), optuna(repo), Webull-Trading-Bot(repo), azure-sql-database-samples(repo), Tiktok-uploader(repo), msrx(repo), automatic-video-montage-editor(repo), cocrawler(repo), mdnd11(user), pinnacle(repo), vaccine_appointments(repo), interpolation(repo), for949(user), PyMuPDF(repo), QuantConnect-Trading-Strategies(repo), PSpider(repo), deepchem(repo), vision-agent-with-llava(repo), Email-Grabber(repo), Binance-News-Sentiment-Bot(repo), pythonh9(user), LWM(repo), betfairutil(repo), GPTeacher(repo), BirdNET-Analyzer(repo), sec-edgar-downloader(repo), crypto-notebooks(repo), alright(repo), APOLLO(repo), dgfantasy(repo), earnalotbot(repo), Deep-Neural-Networks-for-Baseball(repo), LiftSim(repo), shantibarrera(user), mini-agi(repo), PortScanner(repo), LookaheadDecoding(repo), python-for-OSINT-21-days(repo), carefl(repo), austinanthony18(user), ML-Recipes(repo), RealtimeTTS(repo), ai-typing-assistant(repo), infiniteGPT(repo), 1D-Condition-method-pytorch(repo), finplot(repo), GassistPi(repo), honnigmelone(user), KarlaOH(user), starfyre(repo), ARBOT(repo), Betting_system(repo), python-patterns(repo), uebersicht-airpod-status(repo), pymdp(repo), ml-fastvit(repo), dataset(repo), TwitchVault(repo), gaussian-splatting(repo), python-time-series-analysis(repo), rss-chan(repo), djbags(user), Otter(repo), Object-Oriented-Python-Code(repo), vio_ekf_slam(repo), mito(repo), audio2photoreal(repo), django-helpdesk(repo), White-box-Cartoonization(repo), NCP(repo), OFFAT(repo), serverless-application-model(repo), toon3d(repo), edgar-10k-mda(repo), s3prl(repo), GraphGym(repo), Gytbalam(user), MAgent(repo), xtend_tuya(repo), betting-crawler(repo), AutoGen_IterativeCoding(repo), dataprep(repo), barjehkopaxum(user), crewai-updated-tutorial-hierarchical(repo), NoWarDDoS(repo), NodeRelax-Blender-Addon(repo), jupytext(repo), Django-Poll-App(repo), DPSR(repo), Open-Catalyst-Dataset(repo), Wazuh-Rules(repo), RobinhoodShell(repo), blockcypher-python(repo), MAAS(repo), InsiderTrading(repo), Platypus(repo), openwebrx(repo), Test_Grader(repo), georgederr(user), moneymvtch07(user), fifa-FUT-Data(repo), WPForce(repo), robobrowser(repo), BTB-manager-telegram(repo), Awsome-Deep-Learning-for-Video-Analysis(repo), file-validator(repo), ebay-oauth-python-client(repo), RegGNN(repo), clean-code-python(repo), finviz(repo), SeaGOAT(repo), web-avatarify(repo), distribute_crawler(repo), sybil(repo), AI_for_Financial_Data(repo), imc_prosperity(repo), 12_bloom(repo), autogluon(repo), lookwhostalking(repo), app-store-server-library-python(repo), Unichat-llama3-Chinese(repo), CloudMiner(repo), fastapi-tutorial(repo), flask_restx_project(repo), lamda(repo), django-dynamic-scraper(repo), get_subscribe(repo), NHL-Predictor(repo), edsml-xl4323(user), multivariate_time_series_forecasting(repo), start-here-guidelines(repo), pytorch-metric-learning(repo), LLaVA-NeXT(repo), NBA_Bet(repo), stark(repo), wenceser(user), RiskInDroid(repo), FinanceReportAnalysis(repo), NebojsaH(user), hrtshsgfshfggr(user), youtube-transcript-scraper(repo), albeng8(user), checkerboard(repo), Eyoung1000(user), videopose(repo), alex7147gp(user), pjclet(user), HeyGenClone(repo) ...
# Community 2: ai-edu(repo), implied_rnd(repo), LeetCode-Anki(repo), emperors(repo), ssac24(repo), XReplyGPT(repo), investments(repo), zeu(repo), NHLTopScorers(repo), Tennis-Models(repo), Market-Making(repo), jaimeenye(repo), dorem(repo), Dataset(repo), naniar(repo), destack(repo), lotofacil(repo), bryanbraun.github.io(repo), NBA-Simulator---Simple-Model(repo), 2022-08-03-codas-hep-columnar-tutorial(repo), responsive-html-email-template(repo), MagStriper(repo), The-Python-Graph-Gallery(repo), GolfDataApp(repo), VideoSuperResolution(repo), serverless-plugins(repo), RedsHackathon(repo), awesome-creative-coding(repo), chilipie-kiosk(repo), CMS-parser(repo), infra-multi-account-region-startup-kit(repo), B3FD(repo), qf-lib(repo), visdom(repo), radumarica(user), hot-tips(repo), landing-page-template-nextjs(repo), brglm2(repo), hugo-PaperMod(repo), L2J_DataPack(repo), tutmom(repo), StatsBombR(repo), AppleHealthAnalysis(repo), ebnm(repo), ocr-cnh-2-json(repo), NBA-Fantasy-Optimizer(repo), pcc_2e(repo), Deep-Q-Learning-Paper-To-Code(repo), StatGrabber(repo), nanoseq(repo), Football-match-result-prediction-with-R(repo), dashee87.github.io(repo), PyMacroRecord(repo), meta-analytics(repo), sqlworkshops(repo), mike-bostedt(user), r-web-scraping-cheat-sheet(repo), OtherSports(repo), amiddleton162(user), text_editor_gui(repo), CS240(repo), ansible_homelab(repo), stocks(repo), infra-personal(repo), hackathon-toolkit(repo), Xopt(repo), ciao(repo), ND-Pyomo-Cookbook(repo), mind-ar-js(repo), jlmrtnzmrn(user), ESPN-Fantasy-Football-API(repo), traktok(repo), keras(repo), mr.ash.alpha(repo), Beginner-Network-Pentesting(repo), com.ktechpit.colorwall(repo), Dynamic_Nelson_Siegel_Svensson_Kalman_Filter(repo), hexo-theme-alpha-dust(repo), scvi-tools(repo), Football-Prediction-by-Bayesian-Method(repo), mortmafaka(user), chatgpt_telegram_bot(repo), Algorithms_DPV_Solutions(repo), usethis(repo), backtrader-pyqt-ui(repo), first-portfolio(repo), auto-draft(repo), react-world(repo), r-shiny-sports-analytics-app(repo), hyperblog(repo), PlotNeuralNet(repo), BUAAthesis(repo), prescient(user), resume-chinese(repo), dplyr(repo), aws-otel-lambda(repo), Groff(lang), ctwas(repo), WellRestedSloth(user), defense-playmaking(repo), leetcode-anki(repo), LaplacesDemon(repo), sc-type(repo), trilha-html-modulo-1(repo), bmbstats(repo), facetorch(repo), splits-io(repo), ghost-OTPBOT.github.io(repo), connector-API(repo), classy-django-forms(repo), Heart-rate-measurement-using-camera(repo), typed.js(repo), igorss77(user), PersonalAssistantChatbot(repo), Book4_Power-of-Matrix(repo), DataEditR(repo), hoopR-nba-raw(repo), ingestify(repo), goalmodel(repo), NBA-Betting-21-22(repo), hoopR-nba-data(repo), YouTube-I-mostly-use-colab-now-(repo), Phoenix(repo), ML-University(repo), putting(repo), node-html-parser(repo), DataProfiler(repo), optimal-roadtrip-usa(repo), shiny-prod-apps(repo), Rotogrinders-Scraper(repo), docarray(repo), automatic-app-landing-page(repo), POWNFT-miner(repo), RxNorm(repo), pyspark_greatexpectations(repo), Lmod(repo), google-tasks-desktop(repo), stock-ticker(repo), stata-regression(repo), git-with-stata(repo), raspap-webgui(repo), kubetools(repo), youtube-data-analytics-tools(repo), Trading-Algos(repo), terraform-aws-eks-blueprints-addon(repo), pg-collector(repo), betfinder2(repo), balance(repo), jekyll-dash(repo), NBA-RANKINGS-2024(repo), NHLAdjustedGoalDiff(repo), paletteer(repo), homebridge-switchbot(repo), elo(repo), nba-dfs(repo), options(repo), quartotemplate(repo), quant_rv(repo), Blaze(repo), Barbearia-Alura(repo), ci-ms5-ecommerce-game-store(repo), midserver(repo), codechella(repo), whitebox-python(repo), StarWars(repo), Quant-Trading-Cloud-Infrastructure(repo), Murray_D3-Dataviz(repo), PureScript(lang), home-ops(repo), scikit-llm(repo), educational(repo), Kaggle-NCAA-Women-2019-competition(repo), govod(repo), robbiejdunne(user), Phone-number-location-tracker-using-python(repo), tidychatmodels(repo), NBAFinalsPrediction_ML(repo), CiLocks(repo), Liquid(lan ...
# Community 3: abali518(user), bytewax(repo), greenlight(repo), cd0379-computing-with-natural-language(repo), crypto-arbitrage-framework(repo), Credit-Card-Dataset-for-Clustering(repo), mistral-inference(repo), AnimateDiff(repo), mlfinlab(repo), scikit-learn-videos(repo), 3D-printed-mirror-array(repo), multi_vendor_shop_app(repo), solutions(repo), fecon235(repo), mstables(repo), LayoutLMV3_Fine_Tuning(repo), Face-Mask-Detection(repo), probability(repo), sklearn2pmml(repo), people_also_ask(repo), Past-Performance-Book-Tool(repo), defcon31(repo), Hands-On-Graph-Neural-Networks-Using-Python(repo), Traffic-Light-Rules-Expert-System(repo), Python-Machine-Learning-NFL-Game-Predictor(repo), contrastive-ne(repo), ComputerVision-with-PyTorch-Learning-Program(repo), Missile-Guidance-System(repo), crypto-sentiment-analysis(repo), AIAudioTranscriber(repo), FinBERT_feat_eng_for_Momentum_Transformer(repo), NBA-Playoff-Prediction(repo), sagemaker-end-to-end-workshop(repo), NBA-Sports-Betting-model(repo), tensor-house(repo), alphafold3-pytorch(repo), trading-bot(repo), open-geo-tutorial(repo), dinov2_custom_classification(repo), MultiGarmentNetwork(repo), delta-examples(repo), Financial-Modeling(repo), bandit(repo), NHL-Goal-Prediction-Model(repo), Reinforcement-learning-trading-agent-using-Google-trends-data(repo), ykk9595(user), 100-days-of-python(repo), ludwig(repo), fantasy_football(repo), deep-learning-for-finance(repo), LoanDefault-Prediction(repo), PLM-PLI(repo), nbapredictions(repo), Olympic-Medals-Taipy-App(repo), Formula_1(repo), ML_for_betting_on_the_NHL(repo), RFM_Customer_Segmentation(repo), ncaa_camilo(repo), Jazparism(user), asl-ml-immersion(repo), clusterdata(repo), FurucomboWatcher(repo), Stock-Price-Prediction-using-LSTM-and-Technical-Indicators(repo), large-language-models-and-chatgpt-in-three-weeks(repo), easy-scraping-tutorial(repo), NBA-Data(repo), PhotoMaker(repo), Sports-Performance-Analytics(repo), pyfolio(repo), mlflow-deployments(repo), misc(repo), MIRNet-TFJS(repo), tarsier(repo), WANDS(repo), DataCamp-Project-Solutions-Python(repo), didataai(user), Python-For-Beginners(repo), SPORTS(repo), gaussian-splatting-colab(repo), Speech-Datasets-for-ASR(repo), dfs-mlb(repo), Football-Match-Winning-prediction-using-machine-learning(repo), plotly_ipywidget_notebooks(repo), Data-Science-Books(repo), Independent_Component_Analysis(repo), vision_blender(repo), ProBettor(repo), lotto_number_AI(repo), Dylan-Robson(user), jayhova3g(user), Youtube-scraping-using-Selenium(repo), WorldCupPrediction(repo), probabilistic-federated-neural-matching(repo), TrackNet(repo), prophetverse(repo), Football-Data.co.uk(repo), vit-vqgan-jax(repo), tiktok-rss-flat(repo), code_snippets(repo), SQL_lessons(repo), osint-scraper(repo), LLMTest_NeedleInAHaystack(repo), MathPDF2MD(repo), nfl-led-scoreboard(repo), reidd23(user), pyFi(repo), football-match-winner-prediction(repo), PGA-Tour-Shotlink-Analytics(repo), Python_Portfolio__VaR_Tool(repo), xG_Model_Workflow(repo), TextRank-Keyword-Extraction(repo), BioSentVec(repo), FantasyFootballEPL(repo), decentralized-legal-ai(repo), csharp-notebooks(repo), thomaschen2019(user), Deep-Portfolio-Management-Reinforcement-Learning(repo), lineup_optimizer(repo), articles(repo), Quora-Crawler(repo), Efficient_Python_tricks_and_tools_for_data_scientists(repo), ffmpeg-python(repo), Twitter-Sentiment-Analysis-about-ChatGPT(repo), deeplearning.ai(repo), kohya-trainer(repo), Amazing-Feature-Engineering(repo), hred-attention-tensorflow(repo), data-scientist-roadmap(repo), pyx(repo), ai-finance-pencil(repo), march-madness-ml(repo), Data-Analysis-Tennis(repo), Multivariate-time-series-models-in-Keras(repo), StonkBot(repo), keras-inceptionV4(repo), stylegan2-ada-pytorch(repo), podcast-downloader(repo), fantasy-points(repo), best-ball-data-bowl(repo), drl-zh(repo), tf-adversarial(repo), tennis_analysis(repo), pandas-datamatters(repo), NoseBleedSection(repo), btgym(repo), learn_python3_spider(repo), Predicting-Sports(repo), FaceD ...
# Community 4: jusgou(user), sports-betting-arbitrage-project(repo), groofazy(user), every-programmer-should-know(repo), starrocks(repo), hitech777(user), DeepFaceLab(repo), LePetitNewbie(user), planka(repo), Stock_Analysis_For_Quant(repo), gula25(user), siamam(user), Ricardoonz(user), noodle(repo), Tmoney518(user), a4v2d4(user), tweepy(repo), Finance(repo), magicmoam(user), flutter_clickable_regions(repo), dify(repo), superagent(repo), LeetCodeAnimation(repo), qarth(user), V(lang), firecrawl(repo), plane-notify(repo), hensen2(user), mlc-llm(repo), douyin(repo), krys-eth(user), molhck(user), ChatGPT(repo), mmas-money-tracker(repo), yjh200512(user), snscrape(repo), sympy(repo), chasemcolvin(user), Awesome-Hacking(repo), ayesparshh(user), ungoogled-chromium(repo), Leaked-GPTs(repo), aBlindProgrammer(user), py_ball(repo), PythonDataScienceHandbook(repo), anikchatt(user), networkx(repo), personal-security-checklist(repo), webllama(repo), sportsipy(repo), markyu2004(user), LeetCode(repo), f.lux(repo), EliteQuant(repo), itsthedoom(user), guidance(repo), konaendu(user), gpt-automated-web-scraper(repo), Nba-Sports-Betting-Model(repo), WagerBrain(repo), freeStuffDev(repo), Text_to_speech_audiorecord_app(repo), stocksight(repo), kadellsays(user), banking(repo), github-trends(repo), DeepSeek-Coder(repo), aranooke(user), agency-swarm-lab(repo), llIllIllllIIIlllllll(user), nenadskocic(user), maybe(repo), pydantic(repo), nfldata(repo), Awesome-CV(repo), chris-spann(user), alvaritopz(user), jakebirnbach(user), soccerdata(repo), dstk(repo), apple-knowledge(repo), CopilotForXcode(repo), computer-science(repo), python-binance(repo), Stock-Prediction-Models(repo), intelligent-trading-bot(repo), robin_stocks(repo), devika(repo), NBA-Search(repo), HyakuzaO(user), joecaraccio(user), autollm(repo), nhankins(user), YouTube(repo), LLocalSearch(repo), 500-AI-Machine-learning-Deep-learning-Computer-vision-NLP-Projects-with-code(repo), ML-Papers-Explained(repo), AutoGPT(repo), TrollStore(repo), plana-xyz(user), segment-anything(repo), ZY-the-one(user), bszek213(user), awesome-flipperzero-withModules(repo), leezen20(user), typeorm(repo), cr458316(user), data-science(repo), cooptothe(user), dokploy(repo), CarlosAlbaLopez(user), pytorch(repo), pjbruno327(user), PokemonRedExperiments(repo), scferrier(user), Meta-profit(user), chitchatter(repo), leetcode(repo), CHCSVParser(repo), content(repo), audiocraft(repo), LibreChat(repo), AlphaPy(repo), stable-audio-tools(repo), tunetyme(user), mlws1110(user), cursor(repo), cleanlab(repo), prefect(repo), ArbitrageFinder(repo), mustafaxt2(user), binance-trade-bot(repo), theo0650(user), ConnecticutHuskies(user), pandas-ai(repo), OctoBot(repo), mergekit(repo), the-book-of-secret-knowledge(repo), gpt-researcher(repo), fastlane(repo), zacoppotamus(user), uzziwizzle(user), fgergo97(user), codellama(repo), TexasSolver(repo), elevenlabs-python(repo), DKscraPy(repo), rust(repo), surya(repo), wg-easy(repo), Coding-Claud(user), cloudscraper(repo), gpt4V-scraper(repo), llm.c(repo), asciidoctor(repo), Meson(lang), dlt(repo), twelvedata-python(repo), hacktricks(repo), oolite(repo), chatGPT-discord-bot(repo), cool-retro-term(repo), Lennox-wrld(user), Beating-the-House-Identifying-Inefficiencies-in-Sports-Betting-Markets(repo), pykan(repo), ferry(repo), obragame(user), Critlist(user), mhalfya(user), alpaca-lora(repo), JRobert-vs(user), SGX-Full-OrderBook-Tick-Data-Trading-Strategy(repo), python-guide(repo), agru97(user), revanced-manager(repo), jonjohnson34(user), Badges4-README.md-Profile(repo), ChatGPT_Trading_Bot(repo), tinygrad(repo), Ryan-Iacovone(user), gpt4free(repo), BrunoRRSantos(user), plane(repo), i-board(repo), torradopablo(user), fat_free_crm(repo), AgentGPT(repo), recipes(repo), sps18209(user), chatbox(repo), hydra(repo), IOPaint(repo), flutter-kradio-player(repo), superset(repo), Snej-Corleone(user), LaptopHeaven(user), FireBet(repo), private-gpt(repo), IPARanger(repo), vencord.dev(repo), sherlock(repo), JaydenB2023(user) ...
# Community 5: MutChems(repo), cryptolens-python(repo), awesome-llm-json(repo), quotexpy(repo), security-study-plan(repo), google-play-billing(repo), polyfill-service(repo), manywele-collection(repo), salesforce(repo), homebrew-php(repo), pinnacleapi-documentation(repo), Data-Science-Roadmap(repo), continuous-eval(repo), edi-835-parser(repo), awesome-gpts(repo), llm-numbers(repo), awesome-livecoding(repo), BioCreative-V-CDR-Corpus(repo), telegram-affiliate-bot(repo), react-native-tutorial(repo), awesome-react-components(repo), greek-fonts(repo), BuffaloTechnologyCompanies(repo), database-as-a-service(repo), iqoptionbot(repo), IntrinsicAnything(repo), soccer_data_analytics_resources(repo), Awesome-Masked-Autoencoders(repo), Traefik-v2-examples(repo), soccer-analytics-resources(repo), aws-devops-zero-to-hero(repo), Ryzenthosh-HighSierra(repo), DeepLearing-Interview-Awesome-2024(repo), Stocker(repo), asyncpool(repo), synthetic_prophet(repo), hexo-algoliasearch(repo), web-whisper(repo), BS-Roulette-Python(repo), awesome-resty(repo), CommunityWriterPrograms(repo), vsketch(repo), whitelabel(repo), ml-resources(repo), hw_hacking_cheatsheet(repo), docx-mailmerge(repo), ShowMePlace(repo), OpenData(repo), sssstudyy(user), awesome-spider(repo), quotexapi(repo), pyABC(repo), frankcryp(user), CST-MATLAB-API(repo), AIOsense(repo), soccerplots(repo), nba-games-prediction(repo), kmodes(repo), Rainbow-Agent(repo), Awesome-Embodied-Agent-with-LLMs(repo), Better-Python-59-Ways(repo), HighPerfLLMs2024(repo), awesome-job-list(repo), stak3b0t.tl5zRxV9nVtO(repo), quillbot-premium-for-free(repo), umarabid1(user), tabby(repo), awesome-space-books(repo), managers-playbook(repo), misterkiwan(user), WLASL(repo), django-modernize-pro(repo), SupraOracles(repo), CIAJeepDoors(repo), NHL-Predictive-Modeling(repo), How-to-download-and-install-WSA(repo), locust(repo), awesome-hyprland(repo), how-web-works(repo), OnJava8(repo), toapi(repo), XMR-OMEGA-SOLUTION(repo), Emillzz45(user), awesome-gif(repo), Plots.jl(repo), awesome-privacy(repo), DSTrading(repo), rustracer(repo), excel_erpnext(repo), browserforge(repo), CS-GitHubPratica(repo), csgo-osx-linux(repo), loguru(repo), Resources(repo), trendln(repo), just-build-websites(repo), keyswitch_documentation(repo), InstructGLM(repo), DecryptPrompt(repo), Unvoiced(repo), ElkyMart(user), OC-Little-Translated(repo), Julia(lang), datacontract-cli(repo), deep-learning-from-scratch-3(repo), REL1G405(user), DataStack(repo), Data-Science-Interview-Resources(repo), LiquidityGenerator(repo), Databricks-Delta-Live-Table-Demo(repo), NNTwitterBot(repo), bytebytego(repo), TikTok-Shares-Botter(repo), nodejs-secret-manager(repo), molfeat(repo), awesome-iptv(repo), TorBot(repo), BlabSay--collab-(repo), ansible-zero-to-hero(repo), dev-chatgpt-prompts(repo), Iptv-sports.m3u(repo), PySBR(repo), multimodal-mixup(repo), DifferentialEquations.jl(repo), ML-Course-Notes(repo), hackintosh-ryzentosh-TUF_X570-PLUS(repo), magento2-marketplace-social-login(repo), Canadian-Tech-Internships-Summer-2024(repo), Lego_Trend_Analysis_byMaven(repo), prompts-for-edu(repo), Nasdaq-Stock-Exchange-including-Symbols-and-Logos(repo), lawyerbot-capstone(repo), OB_Template(repo), GroebnerBasis.jl(repo), 2018-elections-official(repo), nfl-data(repo), ThinkOrSwimStudies(repo), Dota2-Win-Probability-Prediction(repo), django-machina(repo), www.mlcompendium.com(repo), AniTalker(repo), startup-marketing-checklist(repo), awesome-ethical-hacking-resources(repo), MolPipeline(repo), Knowledge-Graph-Tutorials-and-Papers(repo), cool-contracts(repo), skin.fentastic(repo), awesome-blockchains(repo), Research-Internships-for-Undergraduates(repo), ReEDS-2.0(repo), wazuh-misp(repo), MaddenScraper(repo), Interactive-brokers-python-api-guide(repo), Stephen-Hawking-Books(repo), qmrExchange(repo), au-companies-providing-work-visa-sponsorship(repo), customer-support-llm-chatbot-training-dataset(repo), tsmetric(repo), django-sendfile(repo), sports-1m-dataset(repo), Teaching-Statistics-U ...
# Community 6: split(repo), TalkingHead(repo), swello(repo), instagram-crawler(repo), fantasy-docs-next(repo), jbetancourt8(user), mjml-app(repo), POGOProtos(repo), gourmet(repo), HR-Management-System(repo), litewrite(repo), ComfyUI-Manager(repo), x2js(repo), sports-betting-calculators(repo), dev(repo), traffic-simulation-de(repo), jira_clone(repo), jynfairchild(user), edex-ui(repo), optimize-fantasy-football(repo), learnopencv(repo), clean-rn(repo), instagram-mass-unsender(repo), Web3-Landing-Page(repo), Connect-Telegram-Bot-to-Google-Sheets-ChatGPT-OpenAI(repo), obsidian-advanced-uri(repo), p5js-cheat-sheet(repo), pix-plot(repo), RetWH-react-dashboard(repo), PlayerAVPlay(repo), powercord(repo), tor-links(repo), easysubs(repo), tailblocks(repo), search-by-image(repo), trading-utils(repo), sensibull-realtime-options-api-ingestor(repo), lowdb(repo), node-postgres(repo), nightmare(repo), study-tracker(repo), localtunnel(repo), stuhack(repo), backbone(repo), akamai-collector(repo), awesome-react-native(repo), tailwindui-crawler(repo), st-chat(repo), outlook-generator(repo), github-readme-stats(repo), etherchat(repo), midudev(repo), flask-htmx-tailwind(repo), startup-page(repo), AURA(repo), Visual Basic .NET(lang), nextjs-wordpress-starter(repo), Stock-Dollar-Cost-Averaging-Calculator(repo), next-auth(repo), BuildingNodesDocs(repo), gpt4v-browsing(repo), fullstack-graphql(repo), Badget(repo), Binance-Signal-Bot(repo), robinhoodClone(repo), inbox-manager-agent(repo), react-jwt-auth(repo), vue-cryptoicon(repo), releat(repo), svg2jsx(repo), lodash(repo), ubola-cab-flutter-mern-project(repo), gu(repo), Logo(repo), node-express-mongodb-jwt-rest-api-skeleton(repo), kedro-viz(repo), thai-provinces-visited(repo), UserChromeFiles(repo), webpack(repo), WorkerVless2sub(repo), tikfav(repo), razab(user), qrev(repo), React-Native-Math-App(repo), serverless-dynamodb-backups(repo), validator-stats(repo), facebook-marketplace-autolisting-bot(repo), ethereum-boilerplate(repo), NewJob(repo), minter-dapp(repo), wink-statistics(repo), Orthanc-Tools-JS(repo), mapscii(repo), md(repo), brainwave(repo), browser-laptop(repo), the-one-cert(repo), nativescript-plugin-firebase(repo), rails-purecss(repo), project_ai_summarizer(repo), deriv-com(repo), protocol_v1(repo), yahoo-fantasy-sports-api(repo), fence_lizard_bingo(repo), Web-Testing-Hackathon(repo), node-restify(repo), prueba-tecnica-javascript-senior-fintech(repo), UGATIT(repo), Vue-Node-MongoDB(repo), Nantucket(repo), ejs(repo), chatgpt-functions(repo), webusb-ftdi(repo), Discord-Mass-DM-Tool(repo), Personal-Website(repo), Train-AI-agent-on-mutiple-PDF(repo), serverless(repo), website-change-monitor(repo), email-templates(repo), django-apache2-docker(repo), Keyword-pinger(repo), minegauler(repo), sails(repo), candy-crush-reactjs(repo), pghero(repo), LazyAdmin(repo), pusher-js(repo), AI-Powered-Call-Center-Intelligence(repo), post-call-survey(repo), node-binance-api(repo), emirkico(user), rutificador(repo), staxrip(repo), obsidian-html-plugin(repo), nestjs-boilerplate(repo), futurism-client(repo), agi_computer_control(repo), uzumaki-toolbox(repo), emanueke29(user), word_cloud(repo), bento-starter(repo), crypto-app-react(repo), logidze(repo), bluefin(repo), bot-ws-openai(repo), pg-promise(repo), perfume-website(repo), capturebate-node(repo), gantt(repo), Voyager(repo), GoT_screen_time(repo), Timestamp(repo), jsonform(repo), ipfs-desktop(repo), monio(repo), blooket-hacks(repo), llrt(repo), react-markdown(repo), histovec-beta(repo), browser-image-compression(repo), JeChain(repo), contest(repo), AI-Enabled-B2B-FINTECH-Management(repo), learn-rxjs(repo), QSTK(repo), deliveroo(repo), listen1(repo), PythonRobotics(repo), kevhando(user), react-interactive-paycard(repo), NUC6i5SYH-Hackintosh(repo), maml(repo), explorer(repo), amazon-product-api(repo), demo_quarto_site(repo), Poketwo-Autocatcher(repo), interfaces(repo), ipfs-multihash-on-solidity(repo), mysql-shadow(repo), WeBAD(repo), dicomweb-client(repo), reactio ...
# Community 7: ChartView(repo), DeviceKit(repo), OpenAISwift(repo), sportsBetting(repo), Image2SoundFX-jupyter(repo), civitai-web-scraper(repo), taxonomy-supabase(repo), svgr(repo), buttons(repo), black-scholes(repo), external-adapters-js(repo), react-tailwind-chrome-extension-template(repo), BenRiekes(user), GeoNames-MySQL-DataImport(repo), react-hook-form(repo), ClimaX(repo), auto-dev(repo), PlanePlopper(repo), Awesome-Video-Object-Segmentation(repo), How-to-Downgrade-apps-on-AppStore-with-iTunes-and-Charles-Proxy(repo), testcontainers-node(repo), timer-app(repo), djangosheet(repo), LogicProScripter(repo), DynamicColor(repo), tanstack.com(repo), obsidian-copilot-auto-completion(repo), MaterialTabBar(repo), iOS-DeviceSupport(repo), ScrollingPageControl(repo), Kotlin-Firebase-Group-Chat(repo), SaaS-Template-GPT(repo), faker(repo), expo-lucia-auth-example(repo), vueuse(repo), github-sol-auto-dispenser(repo), RevolutInternalAPI(repo), auto-playwright(repo), live-resume(repo), ethereum.rb(repo), puck(repo), darts(repo), highlight(repo), free-react-tailwind-admin-dashboard(repo), twinny(repo), homebridge-node-alarm-dot-com(repo), esqew(user), mongokit(repo), theHarvester(repo), tiptap(repo), katana(repo), zitadel-nextjs(repo), serverless-project-example(repo), ui-snippets(repo), RIBs(repo), ios-oss(repo), LucidDreamer(repo), GPUImage(repo), serverless-toolkit(repo), CMSScan(repo), next-13-tutorial(repo), RPG-JS(repo), dydx-v3-python(repo), ipatool(repo), open-resume(repo), SyntaxUI(repo), astro-boilerplate-components(repo), Go-real-estate-app(repo), medplum(repo), jstips(repo), Vulcan(repo), animes-house-scraper(repo), shadcn-chat(repo), dentelo(repo), pywinassistant(repo), fanduel-api(repo), NonSteamLaunchers-On-Steam-Deck(repo), globe.gl(repo), medplum-hello-world(repo), Saas-Kit-prisma(repo), swift-concurrency-extras(repo), hi_my_name_is_keyboard(repo), livewallpaper(repo), bexh-frontend-web-reactjs(repo), unstorage(repo), mexc-api-sdk(repo), JJazzLab(repo), langchain-upstash-redis(repo), threepipe(repo), chatbot(repo), lumentis(repo), diffusers.js(repo), DataPassing(repo), electron-react-ts-starter(repo), Todo-List(repo), hadesglobal(user), VisualPinball.Engine(repo), ParaDiffusion(repo), SwiftUIBackports(repo), resuminator(repo), chaskiq(repo), ghostfolio(repo), chatgpt-api(repo), styled-components(repo), odoo(repo), cloudflare-email(repo), actionhero(repo), Swiftlane(repo), cuvs(repo), Swift-Radio-Pro(repo), ebay-api(repo), iRingo(repo), A-DSPy-based-RAG-with-LlamaIndex(repo), appstore-clone(repo), trustsdk-react-native(repo), lottie-ios(repo), lean4(repo), uni-stack(repo), chesspecker(repo), Infinite-Runner-Ultimate(repo), thumbhash(repo), VueTorrent(repo), E2B(repo), bases(repo), iruka(repo), xyflow(repo), pdf-to-img(repo), selfhost(repo), shouldideploy(repo), anytype-ts(repo), swiftui-lazycollectionview(repo), mev-bot(repo), mediapipe-samples(repo), TouchScale(repo), create-t3-turbo(repo), put-call-parity-options-arb(repo), data-and-resources(repo), CodeEdit(repo), NotANumber(repo), Fortran(lang), tip(repo), PushKit_SilentPushNotification(repo), OPNsenseManager(repo), iOS_BackLidarCam(repo), grammY(repo), FullDiskAccess(repo), tact-emulator(repo), obsidian-persistent-graph(repo), SportsApp(repo), defold(repo), snipcart-nextjs(repo), advanced-patterns-workshop(repo), effect(repo), AeroSpace(repo), facebook-ios-sdk(repo), Choose-Your-Own-Adventure-Game(repo), flask-redis-queue(repo), winston(repo), Glur(repo), Factory(repo), Empyrial(repo), themes(repo), tril(repo), wearAmask(repo), puppeteer-heap-snapshot(repo), dorita980(repo), dialog(repo), Swift(lang), obsidian-bmo-chatbot(repo), AppStore-Connect-Widget(repo), expo-router-typescript(repo), TRON(repo), PageView(repo), progressbar.js(repo), light-bootstrap-dashboard-angular2(repo), espeak-ng(repo), react-tweet(repo), jsoncrack.com(repo), ipcam-timelapse(repo), WebRTC-iOS(repo), ignite(repo), qr-code-styling(repo), collegebaseball(repo), gitbook(repo), nba-monte-carlo(repo), ...
# Community 8: IMaker(repo), walle(repo), ntopng(repo), serverless-with-aws(repo), TypeScript(repo), eslint-plugin-roku(repo), forge(repo), logseq-quick-capture(repo), platform_frameworks_base(repo), island(repo), textgenrnn(repo), phantomjs-node(repo), wiki(repo), pelican(repo), howdoi(repo), meteor-client(repo), navisu(repo), DeepImage-an-Image-to-Image-technology(repo), RobotCode2024(repo), NFCMiTM(repo), Minigames(repo), donphan(repo), tsunami-security-scanner(repo), Leetcode-Problems(repo), compute-scroll-into-view(repo), eland(repo), linden_outlawalert(repo), GitHub-Chinese-Top-Charts(repo), trino(repo), landing(repo), vue3-easy-data-table(repo), sqlfluff(repo), monte-carlo-mlb(repo), jupyterlite(repo), cocochan55(user), report_telegram_channels(repo), threedy(repo), memories(repo), AndroidUtilCode(repo), neo-blessed(repo), job-search-resources(repo), alibi(repo), teavm(repo), sonar-flutter(repo), GNews(repo), materio-vuetify-vuejs-admin-template-free(repo), ANDROID_POS_SDK(repo), grocy(repo), Deku-SMS-Android(repo), geoip-attack-map(repo), CodeGPT(repo), awesome-neovim(repo), OSRSBytes(repo), bfit-app(repo), GTOHelper(repo), MonsterMusic(repo), neofetch(repo), fastapi-tips(repo), surrealdb-openai(repo), 1brc(repo), Blog(repo), NBA-ETL-Pipeline(repo), LeetCode-Stats-Card(repo), tudor-cretu(user), oyvey-ported(repo), vegeta(repo), nuxt3-template(repo), DIGITAL Command Language(lang), pyjnius(repo), nvim(repo), FB-Cracker(repo), WireViz(repo), FoxMagiskModuleManager(repo), really-awesome-gan(repo), TwitchMod(repo), opentts(repo), spotify-analysis(repo), DataSurgeon(repo), AndroRAT(repo), FinnishLearner(repo), jellyfin-tizen-builds(repo), bootstrap(repo), BetonQuest(repo), tokapi-client(repo), html5-slot-machine(repo), atbswp(repo), element(repo), toBeTopJavaer(repo), flask-tor(repo), AWESOME-FER(repo), stremio-docker(repo), slipstream(repo), Audnexus.bundle(repo), Books-Inventory(repo), prisma-snippets(repo), gizecarlockerutility(repo), labs(repo), Vinted-data(repo), django-htmx(repo), scalar(repo), crewai-groq(repo), com.jake.retrodial(repo), complete-intro-to-linux-and-the-cli(repo), ysoserial(repo), AI-Aimbot(repo), feed-me-mensa-ul(repo), handycapper(repo), codeium.vim(repo), bookshelf(repo), Anti-Theft-App(repo), node-tenpay(repo), parallel.js(repo), extract-news-api(repo), pytorch-lightning(repo), fhpmensa(repo), blade(repo), DeepSeek-VL(repo), stitch(repo), Facebook-Exploit-Python-(repo), graphql-apis(repo), leet-code(repo), pyobd(repo), Ultimate-Counter-Strike-Movie-Collection(repo), HiperBoot(repo), python_secure_http_file_transfer_using_rsa(repo), dragonstack-guides(repo), OF-Scraper(repo), mturk-code-samples(repo), ssc-asi-tools(repo), Timelk(user), discord-oauth2(repo), runelite(repo), newcar(repo), alternative-front-ends(repo), C4-PlantUML(repo), Xtend(lang), scrollreveal(repo), webmagic(repo), node-appdmg(repo), dockit(repo), science-parse(repo), metasfresh(repo), InventoryManagementSystem(repo), github-matrix(repo), ftw(repo), honeymap(repo), X-osint(repo), PC-DARTS(repo), DiceBotScripts(repo), coffeescript(repo), alacritty(repo), gen.nvim(repo), Sudoku-Solver(repo), GScan(repo), mevn-boilerplate(repo), tailwind-admin-template(repo), trueskill(repo), pihole-regex(repo), Awesome-AutoDL(repo), openapi2kong(repo), jsonpickle(repo), react-admin(repo), Ali_Clone(repo), awpy(repo), thefuck(repo), POSLink-UI(repo), JDA(repo), cvs0(user), nhl-score-api(repo), eggs(repo), SRKAKASHI(repo), twilio-voice-android(repo), eslint-config-standard(repo), html-tailwindcss-components(repo), osrs-gui-bots(repo), polyglot.js(repo), ansible(repo), App(repo), vue-final-modal(repo), ethan-hurst(user), devbrasuca(user), bcrypt(repo), startbootstrap-sb-admin(repo), xg2xg(repo), pyTibber(repo), HackerRank_solutions(repo), io.appium.settings(repo), lambda-sample-events(repo), cryptomator(repo), lstm-char-cnn(repo), im-server(repo), stripe-demo-connect-kavholm-marketplace(repo), DemoCulqiOtc(repo), oauth(repo), PokerGto(repo), koreader(rep ...
# Community 9: attack-surface-framework(repo), qlattes(repo), IPTV(repo), mac(repo), orbstack(repo), hackbox(repo), simple-llm-finetuner(repo), Watch-Me-Build-a-Trading-Bot(repo), firefox-gx(repo), books-dl(repo), xhunter(repo), codeium.el(repo), awesome-roadmaps(repo), LFiFreak(repo), Hepziba97(user), MFASweep(repo), Sn1per(repo), opengapps(repo), firefox-gnome-theme(repo), Chat2DB(repo), CloudUnflare(repo), pico-ducky(repo), zoraxy(repo), Tiny-PowerShell-Projects(repo), UFC-Fight-Prediction-Repo(repo), setup-python(repo), HASH(repo), pwnedOrNot(repo), zsh-nix-shell(repo), PIZZAbite(repo), win10-bluetooth-headphones(repo), dalle-mini(repo), gajira-cli(repo), markwhen(repo), learn_elisp_the_hard_way(repo), porch-pirate(repo), cumulative-table-design(repo), r3f-ts-drei-starter(repo), azure-search-openai-demo(repo), SongTube-App(repo), cool_python_apps(repo), JPG-RAT(repo), beehive(repo), LaTeX-Workshop(repo), DestinyItemRater(repo), Sketchpad(repo), osintmap(repo), python-o365(repo), NSC_BUILDER(repo), cdn-proxy(repo), photon(repo), nadiration(user), htn-financial-analysis-ai(repo), bazzite(repo), UniFi-Video-Controller(repo), chelydra(repo), 100-days-of-code(repo), reconftw(repo), active-scanning-techniques(repo), CVE-2021-3129(repo), zotero-voyant-export(repo), SpyLogger(repo), awesome-css-frameworks(repo), RedTiger-Tools(repo), flowable-engine(repo), codespaces-project-template-js(repo), prismarine-viewer(repo), LunchBot(repo), sanctuary-internal-tools(repo), BrutePress(repo), TrollStore-IPAs(repo), textmate-freemarker-bundle(repo), git-secrets(repo), awesome-kubernetes-security(repo), Bug-bounty-Writeups(repo), gau(repo), lorabridge(repo), open-tv(repo), TalkWithGemini(repo), Teams-Presence(repo), Nix(lang), big-list-of-naughty-strings(repo), ReelSteady-Joiner(repo), ProductHunt-Clone(repo), 120-perguntas-frontend(repo), misaka(repo), linux-gameservers(repo), stakeBOB(repo), Hunner(repo), markdown-online-editor(repo), svelte-address-autocomplete(repo), ESFileExplorerOpenPortVuln(repo), jinx(repo), Retrograde(repo), ani-cli(repo), awesome-janet(repo), kaffy(repo), Emacs Lisp(lang), robinkaulfuss(user), statichunt(repo), theZoo(repo), TheBigPromptLibrary(repo), OCRmyPDF(repo), Drop(repo), yolov8_fastapi_gradio(repo), MEAT(repo), revanced-magisk-module(repo), nuclei(repo), wagtailgridder(repo), flutter_training_app(repo), plugin.program.autowidget(repo), awesome-embedded-and-iot-security(repo), mac-setup(repo), awesome-certificates(repo), Eviltwin-Huawei_XD(repo), autotorrent2(repo), hexoblog(repo), run-fullnode-eth(repo), pornhub(repo), httprebind(repo), hassio-addons(repo), destiny-loadout-builder(repo), openapi-backend(repo), lazyaircrack(repo), reactjs-appwrite_userauth(repo), Org(lang), 30-Days-Of-JavaScript(repo), CSSWENG-Team-3(repo), starfield-xgp-import(repo), PornBotHunter(repo), inventory(repo), power-platform(repo), setup-new-computer-script(repo), aws_stealth_perm_enum(repo), legion-go-tricks(repo), awesome-google-vrp-writeups(repo), zmuhls(user), v2ray(repo), presalewebsite(repo), TunnelVision(repo), ha-alexa-tts(repo), palen1x(repo), MachineLearning6.867(repo), EHTools(repo), tensortrade(repo), tap-type-python(repo), TodoApp(repo), react-wp-scripts(repo), vsc-python-indent(repo), nextjs-openai-doc-search(repo), headless-recorder(repo), PoShFuck(repo), astro-cube(repo), LinEnum(repo), mindmaps(repo), bookcut(repo), TrackerChecker(repo), teams-client(repo), warp(repo), tracker-radar(repo), pgmc_cd_2023(repo), Personal-Portfolio(repo), remix(repo), AnimatedDrawings(repo), browserify-handbook(repo), sampler(repo), Hack(lang), noty(repo), bitwarden_gcloud(repo), xiringuito(repo), browser-sync(repo), Gherkin(lang), data-engineering-wiki(repo), noten(repo), vue-kraken(repo), h4cker(repo), PairDrop(repo), react-native-boilerplate(repo), byob(repo), node-speaker(repo), DevSecOpsGuideline(repo), binance-copy-bot(repo), flask-black-dashboard(repo), InternetArchive-scripts(repo), hardware-hackme-1-eda(repo), inlood(user), bpy ...
# Community 10: winetricks(repo), tailwind-login-template(repo), rek79(user), openbao(repo), gophish(repo), hwameistor(repo), aws-drift-detector-slack(repo), game-datasets(repo), rancher(repo), datalayer-event-repeater(repo), cockroach(repo), MobaXterm-GenKey(repo), stylegan-t(repo), tree-of-thought-llm(repo), create-pull-request(repo), Spark(repo), httprouter(repo), deepface(repo), ntopng-exporter(repo), node-facenet(repo), nodejs-express-rest-api(repo), zitadel(repo), cascade(repo), Desktop-Client(repo), caddy(repo), oddsportal-archive-scraper(repo), Decrypted-IPAs(repo), ecs-deep-dive-2018(repo), octokit.js(repo), fineract(repo), fullstack-graphql-movies(repo), version-manager(repo), HomeHarvest(repo), watermill(repo), webhook(repo), Dockerfile(lang), otomi-core(repo), polaris(repo), carve(repo), fireworq(repo), Real-Time-Violence-Detection-in-Video-(repo), liquidation-bot-fall-2020(repo), colima(repo), javascript-style-guide(repo), RSS-to-Telegram-Bot(repo), react-native-dropdown-select-list(repo), walker(repo), hatchet(repo), py-machineid(repo), rtlamr(repo), WhiteSur-gtk-theme(repo), go-best-practice(repo), dae(repo), devpod(repo), argo-helm(repo), dolt(repo), ctop(repo), Klang(repo), supersonic(repo), building-microservices-youtube(repo), vConsole(repo), dl_remote(repo), stockpyl(repo), nunu(repo), .archive(repo), flyte(repo), xinmans(user), elixir-sublime-syntax(repo), django-rest-framework(repo), uspto(repo), bots-fw(repo), bybit_scalp_bot_v2(repo), decompose(repo), ntfy(repo), serving(repo), docker-borgmatic(repo), facenet-face-recognition(repo), owncast(repo), cdk-constructs(repo), spr(repo), adblockfilters(repo), Paper(repo), Go-Hacking(repo), beekeeper-studio(repo), HackBrowserData(repo), LeetCode-Go(repo), essays-on-data-science(repo), httprobe(repo), swagger-codegen(repo), difftaichi(repo), color(repo), incubator-answer(repo), littlelink(repo), dockersample(repo), FlexGen(repo), watchtower(repo), dynamic-nfs-provisioner(repo), websocket(repo), git-backdate(repo), causalEntropicForces(repo), pg-transactional-outbox(repo), memos(repo), fiftyone(repo), Taiwan-LLM(repo), goscore(repo), 0q2(user), Project-Quantum(repo), transfer.sh(repo), werbot(repo), webping.cloud(repo), civboot(repo), cvemap(repo), fastpat(repo), ysenhu(user), acacia_main(repo), swissgl(repo), web-app(repo), fastText(repo), Predicting-Stock-Prices-with-Linear-Regression(repo), Best-Flutter-UI-Templates(repo), preguntas-entrevista-react(repo), J4mez(user), go-observability-example(repo), pix2pix3D(repo), shermie-proxy(repo), golang-clean-architecture(repo), datadog-to-terraform(repo), solace-single-docker-compose(repo), argparse(repo), beego(repo), typeid(repo), onionpipe(repo), golang-httpflood(repo), go-design-pattern(repo), OpenChat(repo), Go(lang), simplify(repo), StoryDiffusion(repo), go-proxy-cache(repo), go-json(repo), nostr-webhost(repo), horcrux(repo), democracyos(repo), SmashBot(repo), AdGuardHome(repo), Face-Detection-and-Recognition-on-Google-Glass(repo), 403jump(repo), pico(repo), bridget(repo), r-placer(repo), OpenGFW(repo), nfs-subdir-external-provisioner(repo), py3-pinterest(repo), pbs-exporter(repo), hanko(repo), go-shadowsocks2(repo), realworld(repo), comments-with-polygon(repo), Espada(repo), codequestion(repo), trickster(repo), PySDR(repo), libp2p(repo), opencx(repo), gose(repo), sops(repo), bit(repo), dashboard(repo), source-to-image(repo), pyicloud(repo), wstg(repo), hello-nav(repo), SeedcrackerX(repo), gpt4-openai-api(repo), cleanenv(repo), cosmos-cash(repo), blockchain-node(repo), tsk(repo), lunr-languages(repo), sling-cli(repo), viper(repo), ComfyUI-Docker(repo), cero(repo), bubbles(repo), gopportunities(repo), extension-cpp(repo), geometric-algebra-transformer(repo), lnd(repo), vitest(repo), Adalanche(repo), fastify-graphql-api(repo), typescript-ddd-forum(repo), LoginWeb(repo), stock-api(repo), huey(repo), actionlint(repo), tldrstory(repo), ketch(repo), bootdev(repo), fyne(repo), trillian(repo), Predicting-Football-Match-Out ...
# Community 11: country-list(repo), Microsoft(repo), countries-states-cities-database(repo), Submitty(repo), Hiper-ChatGPT(repo), craco(repo), UFO(repo), cryptocurrency-arbitrage(repo), memesplash(repo), tpotce(repo), vitamin(repo), baseball-odds(repo), KaTeX(repo), avatar-graph-comfyui(repo), vue-onoff-toggle(repo), rss-bridge(repo), routing(repo), Monocraft(repo), hand-gesture-recognition-mediapipe(repo), ClassControlPanelMQL5(repo), OpenKomodoIDE(repo), Blade(lang), livewire-charts(repo), ovoid(repo), design-systems(repo), CodeIgniter(repo), exploit-notes(repo), action-recognition-pytorch(repo), FeedWriter(repo), django-vue-admin(repo), corcel(repo), jquery-creditcardvalidator(repo), jmespath.php(repo), laravel-datatables(repo), sqlcommenter(repo), poe-api(repo), pyllama(repo), Providers(repo), VietAI-NTI_ChatGPTStreamlit(repo), youtube-downloader(repo), production-tools(repo), wp-optimize(repo), kanboard(repo), betfair-datascientists.github.io(repo), omni-zero(repo), headstart(repo), SubGhz_Cust_Serv(repo), filament-versionable(repo), ML(repo), tenancy(repo), vr-dos(repo), PrestaShop(repo), flaskSaaS(repo), fastapi-admin(repo), Invite-Referral-System(repo), MQL5-Bots(repo), evershop(repo), filament-timesheets(repo), laravel-keycloak-guard(repo), debug(repo), isbot(repo), htmlpagedom(repo), basic-crud(repo), cob05(user), HotaruCMS(repo), FreshRSS(repo), breeze-next(repo), alphavantage(repo), hacktricks-cloud(repo), YetiForceCRM(repo), vscode(repo), eSkola_veba(repo), outline(repo), DVWA(repo), country-data(repo), xml-wrangler(repo), FreeBotCoin(repo), dokan-custom-payment-method-for-vendor(repo), gansformer(repo), laravel-id-generator(repo), NetPad(repo), php-curl-class(repo), YUI-CSS-compressor-PHP-port(repo), brainy(repo), filament-activity-log(repo), socialment(repo), nextjs-realtime-chat(repo), dynamic-dashboard(repo), RFIDIOt(repo), tab-transformer-pytorch(repo), draftkings_value_estimation(repo), service.vpn.manager(repo), openmediavault(repo), filament-select-tree(repo), portal-news(repo), natural-language-image-search(repo), project_next13_car_showcase(repo), minecraft-weekend(repo), free-money(repo), Kodistubs(repo), laravel-adjacency-list(repo), laravel-log-viewer(repo), laravel-ddd-example(repo), polyfill-php56(repo), zxing(repo), handesk(repo), filament(repo), passbolt_api(repo), Hacki(repo), swrv(repo), Optiver_RTG_Workshop(repo), zend-stdlib(repo), vue3-steppy(repo), ChatHTMX(repo), mautic(repo), s2orc(repo), electrik(repo), kubeflow-mlflow(repo), kibana(repo), PlugBot-Plug(repo), Carding-Tool-by-EvilDevil(repo), newspaper(repo), filament-quick-create(repo), pest-action(repo), hanzi-writer(repo), volt(repo), see-non-printable-characters(repo), pagekit(repo), cookiecutter-flask(repo), react-spline(repo), PHPageBuilder(repo), html5-device-mockups(repo), freakyfreakfreak(user), php-ml(repo), image-optimizer(repo), wp-dispensary(repo), the-most-starred-readme(repo), crypto-prediction(repo), business-machine-learning(repo), sportspredictor(repo), tailwind-variants(repo), vue-api-query(repo), XVideos-PornHub-RedTube-API(repo), instagram-php-scraper(repo), phpdotenv(repo), Financial-Modeling-Prep-API(repo), drawjs(repo), entrust(repo), drupal10(repo), youtube-video-maker(repo), Prequel(repo), aleph-alpha-client(repo), typesense(repo), marketplacekit(repo), Sentiment-analysis-of-financial-news-data(repo), rips(repo), nextadmin(repo), vue-draggable-plus(repo), osCommerce-V4(repo), sanctum-tokens(repo), scp-action(repo), rome-webshell(repo), livewire(repo), css-selector(repo), passport(repo), termwind(repo), howto-make-more-money(repo), math-php(repo), fast-stable-diffusion(repo), dbf2sql(repo), real-estate-site(repo), react-draggable(repo), laravel-video-chat(repo), hostfiles(repo), saas-starter-kit(repo), groq-php(repo), akaunting(repo), kyoushi-environment(repo), instagram-data-scraper(repo), migrations-generator(repo), laravel-otp(repo), tailwind-nextjs-starter-blog(repo), starlite-pg-redis-docker(repo), Laravel-Chall ...
# ...
# Top 10 nodes by degree distribution in Community 3: [('Jupyter Notebook(lang)', 1008), ('matti410(user)', 44), ('playskool1(user)', 42), ('basilghauri(user)', 41), ('reidd23(user)', 39), ('AndreiBacu(user)', 38), ('oguzcatal(user)', 38), ('Cojinsky(user)', 38), ('makdoudN(user)', 38), ('AI-ctrl(user)', 38)]
# Top 10 nodes by degree distribution in Community 4: [('NBA-Machine-Learning-Sports-Betting(repo)', 371), ('Ruby(lang)', 89), ('Dart(lang)', 71), ('ChatGPT_Sports_Betting_Bot(repo)', 54), ('sports-betting(repo)', 53), ('public-apis(repo)', 45), ('Objective-C(lang)', 41), ('AutoGPT(repo)', 40), ('llSourcell(user)', 39), ('cadekeenan(user)', 38)]
# Top 10 nodes by degree distribution in Community 5: [('(lang)', 935), ('Xabo-RB(user)', 49), ('eugene254-ship-it(user)', 40), ('lorenzoliuzzo(user)', 39), ('Julia(lang)', 38), ('ZhiliWang(user)', 35), ('nk6june(user)', 34), ('Rishirandhawa(user)', 31), ('FFWW2023(user)', 30), ('DeemanOne(user)', 29)]
# Top 10 nodes by degree distribution in Community 6: [('JavaScript(lang)', 1015), ('Nathnaelmesfin(user)', 39), ('emanueke29(user)', 38), ('MegaRosss(user)', 38), ('mostlyerror(user)', 38), ('semicirculomx(user)', 37), ('Prat617(user)', 36), ('emirkico(user)', 34), ('tajpouria(user)', 33), ('shredthaGNAR(user)', 32)]
# Top 10 nodes by degree distribution in Community 7: [('TypeScript(lang)', 736), ('Swift(lang)', 256), ('michaelgillund(user)', 49), ('theorangajang(user)', 44), ('gogorr1(user)', 43), ('5uper0(user)', 42), ('labi1240(user)', 39), ('vduquette(user)', 39), ('maxbbb(user)', 39), ('tesths(user)', 38)]
# Top 10 nodes by degree distribution in Community 8: [('Java(lang)', 313), ('Vue(lang)', 73), ('Lua(lang)', 66), ('jaredthecoder(user)', 48), ('CeephasM(user)', 43), ('trymthoren(user)', 39), ('MAZLUM-62(user)', 37), ('JoelSalas22(user)', 36), ('OrochiBr(user)', 35), ('NicoMancinelli(user)', 35)]
# Top 10 nodes by degree distribution in Community 9: [('Shell(lang)', 289), ('CSS(lang)', 118), ('PowerShell(lang)', 49), ('cpjolicoeur(user)', 47), ('MaxKolle(user)', 44), ('Parklife05(user)', 41), ('zmuhls(user)', 40), ('gatensj(user)', 39), ('JkDevArg(user)', 39), ('LasitoBoy(user)', 38)]
# Top 10 nodes by degree distribution in Community 10: [('Go(lang)', 503), ('ikelkar(user)', 45), ('JerimyTate(user)', 44), ('Dockerfile(lang)', 43), ('jmargieh(user)', 41), ('henrylao(user)', 41), ('RogerHiguerey(user)', 40), ('barthezslavik(user)', 37), ('marselzaripov(user)', 37), ('0q2(user)', 36)]
# Top 10 nodes by degree distribution in Community 11: [('PHP(lang)', 456), ('christian-forgacs(user)', 51), ('brentpep(user)', 49), ('oscar-rey-mosquera(user)', 45), ('cob05(user)', 42), ('doctorbinsibar(user)', 42), ('itwela(user)', 42), ('ManukMinasyan(user)', 42), ('kodjunkie(user)', 39), ('qxvlada(user)', 39)]
# Top 10 nodes by degree distribution in Community 12: [('Rust(lang)', 328), ('Solidity(lang)', 84), ('marissaposner(user)', 46), ('Frederick-Levins(user)', 45), ('mkilpat(user)', 45), ('pkayfire(user)', 45), ('hkey0(user)', 44), ('juliaabrams(user)', 43), ('Zumus(user)', 43), ('MarvinL96(user)', 42)]
# Top 10 nodes by degree distribution in Community 13: [('C(lang)', 368), ('Kotlin(lang)', 108), ('rxqbi(user)', 48), ('yourgodfather12(user)', 38), ('antogerva(user)', 38), ('COOLasHEL(user)', 38), ('TopGun666(user)', 36), ('OSU78(user)', 34), ('ysnbogt(user)', 34), ('drewtenn(user)', 34)]
# Top 10 nodes by degree distribution in Community 14: [('C++(lang)', 520), ('uzairgheewala(user)', 43), ('arod79sae(user)', 42), ('grigolin(user)', 41), ('Mj23978(user)', 40), ('wanghuayou1028(user)', 39), ('m-1806(user)', 38), ('bartcctv(user)', 37), ('nickocodes(user)', 36), ('ramAdam(user)', 35)]
# Top 10 nodes by degree distribution in Community 15: [('C#(lang)', 370), ('zcensa(user)', 49), ('coondog024(user)', 46), ('MattFromRVA(user)', 45), ('cryptocoinserver(user)', 43), ('sact1909(user)', 42), ('misaon(user)', 42), ('Element21(user)', 39), ('Gaserd(user)', 39), ('q32854978lhy(user)', 38)]
# Key nodes in Community 1 (sorted by degree centrality): [('Python(lang)', 0.9647058823529412), ('pandabayo(user)', 0.019457013574660634), ('AmauryLfvr(user)', 0.01764705882352941), ('gauvainrobert(user)', 0.0167420814479638), ('vanIvan(user)', 0.016289592760180997)]
# Key nodes in Community 1 (sorted by betweenness centrality): [('Python(lang)', 0.9971793603745779), ('retoga(user)', 0.009066365690337145), ('jmoswalt(user)', 0.007289799647267759), ('nova-land(user)', 0.006378062594609875), ('ShawnZDesign(user)', 0.00593031445959308)]
# Key nodes in Community 1 (sorted by closeness centrality): [('Python(lang)', 0.9659090909090909), ('pandabayo(user)', 0.49607182940516276), ('jmoswalt(user)', 0.4959605026929982), ('retoga(user)', 0.49573799910273664), ('AmauryLfvr(user)', 0.4956268221574344)]
# Key nodes in Community 2 (sorted by degree centrality): [('HTML(lang)', 0.28753993610223644), ('R(lang)', 0.21405750798722045), ('stephenkocsis14(user)', 0.03194888178913738), ('PatrickJohnston(user)', 0.030031948881789138), ('JaimeeNye(user)', 0.030031948881789138)]
# Key nodes in Community 2 (sorted by betweenness centrality): [('HTML(lang)', 0.6847189932854352), ('R(lang)', 0.33136314155786445), ('stephenkocsis14(user)', 0.057072434710253916), ('DylansDecoded(user)', 0.05672196763880037), ('TribridStudio(user)', 0.04901591422206158)]
# Key nodes in Community 2 (sorted by closeness centrality): [('HTML(lang)', 0.5142951035162668), ('R(lang)', 0.40979313956533125), ('PatrickJohnston(user)', 0.40283140283140284), ('stephenkocsis14(user)', 0.40159096741082884), ('eddwebster(user)', 0.4012820512820513)]
# Key nodes in Community 3 (sorted by degree centrality): [('Jupyter Notebook(lang)', 0.65625), ('matti410(user)', 0.028645833333333332), ('playskool1(user)', 0.02734375), ('basilghauri(user)', 0.026692708333333332), ('reidd23(user)', 0.025390625)]
# Key nodes in Community 3 (sorted by betweenness centrality): [('Jupyter Notebook(lang)', 0.9865031027566659), ('reidd23(user)', 0.039952082579321986), ('makdoudN(user)', 0.03677665807093738), ('AI-ctrl(user)', 0.03487759568403909), ('KAI-YUE(user)', 0.032939258731451315)]
# Key nodes in Community 3 (sorted by closeness centrality): [('Jupyter Notebook(lang)', 0.7434656340755083), ('datasets(repo)', 0.4357446808510638), ('reidd23(user)', 0.43500424808836025), ('playskool1(user)', 0.4345120226308345), ('makdoudN(user)', 0.4345120226308345)]
# Key nodes in Community 4 (sorted by degree centrality): [('NBA-Machine-Learning-Sports-Betting(repo)', 0.25835654596100277), ('Ruby(lang)', 0.06197771587743733), ('Dart(lang)', 0.04944289693593315), ('ChatGPT_Sports_Betting_Bot(repo)', 0.037604456824512536), ('sports-betting(repo)', 0.03690807799442897)]
# Key nodes in Community 4 (sorted by betweenness centrality): [('NBA-Machine-Learning-Sports-Betting(repo)', 0.6513661788964008), ('Ruby(lang)', 0.046065187533009096), ('Dart(lang)', 0.02989156757844839), ('TTTTimmy(user)', 0.018476754961104385), ('hitech777(user)', 0.01653996151468801)]
# Key nodes in Community 4 (sorted by closeness centrality): [('NBA-Machine-Learning-Sports-Betting(repo)', 0.5741703318672531), ('llSourcell(user)', 0.4085348506401138), ('cadekeenan(user)', 0.3801959226899656), ('TTTTimmy(user)', 0.3801959226899656), ('hitech777(user)', 0.3798941798941799)]
# Key nodes in Community 5 (sorted by degree centrality): [('(lang)', 0.6650071123755334), ('Xabo-RB(user)', 0.03485064011379801), ('eugene254-ship-it(user)', 0.02844950213371266), ('lorenzoliuzzo(user)', 0.027738264580369845), ('Julia(lang)', 0.02702702702702703)]
# Key nodes in Community 5 (sorted by betweenness centrality): [('(lang)', 0.9826014227643746), ('Xabo-RB(user)', 0.06817374300423565), ('lorenzoliuzzo(user)', 0.05509909234951376), ('eugene254-ship-it(user)', 0.044173707327856054), ('FFWW2023(user)', 0.03804640002429851)]
# Key nodes in Community 5 (sorted by closeness centrality): [('(lang)', 0.7342036553524804), ('Xabo-RB(user)', 0.44423380726698264), ('lorenzoliuzzo(user)', 0.4411672419203012), ('eugene254-ship-it(user)', 0.44047619047619047), ('yrgdro999(user)', 0.4339506172839506)]
# Key nodes in Community 6 (sorted by degree centrality): [('JavaScript(lang)', 0.7441348973607038), ('Nathnaelmesfin(user)', 0.028592375366568914), ('emanueke29(user)', 0.02785923753665689), ('MegaRosss(user)', 0.02785923753665689), ('mostlyerror(user)', 0.02785923753665689)]
# Key nodes in Community 6 (sorted by betweenness centrality): [('JavaScript(lang)', 0.9894714973490448), ('Prat617(user)', 0.044955925668537795), ('Nathnaelmesfin(user)', 0.036376115305422105), ('mostlyerror(user)', 0.0356363435553079), ('tajpouria(user)', 0.03203376629523885)]
# Key nodes in Community 6 (sorted by closeness centrality): [('JavaScript(lang)', 0.79533527696793), ('Prat617(user)', 0.453156146179402), ('Nathnaelmesfin(user)', 0.45240464344941955), ('mostlyerror(user)', 0.45225464190981435), ('tajpouria(user)', 0.45105820105820105)]
# Key nodes in Community 7 (sorted by degree centrality): [('TypeScript(lang)', 0.5415746872700515), ('Swift(lang)', 0.188373804267844), ('michaelgillund(user)', 0.036055923473142015), ('theorangajang(user)', 0.03237674760853569), ('gogorr1(user)', 0.03164091243561442)]
# Key nodes in Community 7 (sorted by betweenness centrality): [('TypeScript(lang)', 0.8258062110688338), ('Swift(lang)', 0.2227230991367643), ('gogorr1(user)', 0.05298939138736701), ('vduquette(user)', 0.0488055576845678), ('michaelgillund(user)', 0.045369131567729225)]
# Key nodes in Community 7 (sorted by closeness centrality): [('TypeScript(lang)', 0.6546242774566474), ('gogorr1(user)', 0.4488110964332893), ('vduquette(user)', 0.44748106684227856), ('esqew(user)', 0.4468924695823742), ('benjohnston(user)', 0.4467455621301775)]
# Key nodes in Community 8 (sorted by degree centrality): [('Java(lang)', 0.2599667774086379), ('Vue(lang)', 0.0606312292358804), ('Lua(lang)', 0.054817275747508304), ('jaredthecoder(user)', 0.03986710963455149), ('CeephasM(user)', 0.03571428571428571)]
# Key nodes in Community 8 (sorted by betweenness centrality): [('Java(lang)', 0.7381942212192655), ('Lua(lang)', 0.1916872285924524), ('Vue(lang)', 0.112313224828268), ('jaredthecoder(user)', 0.0689331059498642), ('CeephasM(user)', 0.06258043339120611)]
# Key nodes in Community 8 (sorted by closeness centrality): [('Java(lang)', 0.5046102263202011), ('jacz24(user)', 0.3865168539325843), ('devbrasuca(user)', 0.38466453674121404), ('wtp43(user)', 0.38380618425247054), ('Muzych(user)', 0.3835616438356164)]
# Key nodes in Community 9 (sorted by degree centrality): [('Shell(lang)', 0.25507502206531335), ('CSS(lang)', 0.10414827890556046), ('PowerShell(lang)', 0.04324801412180053), ('cpjolicoeur(user)', 0.04148278905560459), ('MaxKolle(user)', 0.03883495145631068)]
# Key nodes in Community 9 (sorted by betweenness centrality): [('Shell(lang)', 0.6700945225437511), ('CSS(lang)', 0.2981292198388462), ('PowerShell(lang)', 0.087824809962635), ('cpjolicoeur(user)', 0.08086663131758112), ('MaxKolle(user)', 0.06921542764437325)]
# Key nodes in Community 9 (sorted by closeness centrality): [('Shell(lang)', 0.5209195402298851), ('CSS(lang)', 0.4129008746355685), ('MaxKolle(user)', 0.3905549810410203), ('LasitoBoy(user)', 0.38907967032967034), ('jontstaz(user)', 0.38881262868908717)]
# Key nodes in Community 10 (sorted by degree centrality): [('Go(lang)', 0.49313725490196075), ('ikelkar(user)', 0.044117647058823525), ('JerimyTate(user)', 0.043137254901960784), ('Dockerfile(lang)', 0.04215686274509804), ('jmargieh(user)', 0.040196078431372545)]
# Key nodes in Community 10 (sorted by betweenness centrality): [('Go(lang)', 0.9154820517237545), ('Dockerfile(lang)', 0.1294964290372136), ('ikelkar(user)', 0.08916752874958751), ('henrylao(user)', 0.08764803009852963), ('J4mez(user)', 0.07249178463229176)]
# Key nodes in Community 10 (sorted by closeness centrality): [('Go(lang)', 0.6181818181818182), ('ikelkar(user)', 0.4194078947368421), ('henrylao(user)', 0.41649652919559005), ('J4mez(user)', 0.4158173664900122), ('JerimyTate(user)', 0.41514041514041516)]
# Key nodes in Community 11 (sorted by degree centrality): [('PHP(lang)', 0.4474975466143277), ('christian-forgacs(user)', 0.05004906771344455), ('brentpep(user)', 0.04808635917566241), ('oscar-rey-mosquera(user)', 0.04416094210009813), ('cob05(user)', 0.04121687929342492)]
# Key nodes in Community 11 (sorted by betweenness centrality): [('PHP(lang)', 0.9503272925281291), ('itwela(user)', 0.09018547035642646), ('kristianh001(user)', 0.06780678292166306), ('kodjunkie(user)', 0.06739769021393613), ('BugOrFeature(user)', 0.06557180113533763)]
# Key nodes in Community 11 (sorted by closeness centrality): [('PHP(lang)', 0.635286783042394), ('online-sports-betting(repo)', 0.40923694779116465), ('laravel(repo)', 0.4059760956175299), ('itwela(user)', 0.4059760956175299), ('kristianh001(user)', 0.40244865718799366)]
# Key nodes in Community 12 (sorted by degree centrality): [('Rust(lang)', 0.32443125618199803), ('Solidity(lang)', 0.0830860534124629), ('marissaposner(user)', 0.04549950544015826), ('Frederick-Levins(user)', 0.044510385756676554), ('mkilpat(user)', 0.044510385756676554)]
# Key nodes in Community 12 (sorted by betweenness centrality): [('Rust(lang)', 0.7991091906986363), ('Solidity(lang)', 0.2652246708350366), ('Frederick-Levins(user)', 0.10465676679297113), ('juliaabrams(user)', 0.09855988601544913), ('pkayfire(user)', 0.0876726627021894)]
# Key nodes in Community 12 (sorted by closeness centrality): [('Rust(lang)', 0.5260145681581686), ('Frederick-Levins(user)', 0.39584964761158964), ('juliaabrams(user)', 0.3930793157076205), ('pkayfire(user)', 0.3904982618771727), ('marissaposner(user)', 0.3904982618771727)]
# Key nodes in Community 13 (sorted by degree centrality): [('C(lang)', 0.36435643564356435), ('Kotlin(lang)', 0.10693069306930693), ('rxqbi(user)', 0.047524752475247525), ('yourgodfather12(user)', 0.03762376237623762), ('antogerva(user)', 0.03762376237623762)]
# Key nodes in Community 13 (sorted by betweenness centrality): [('C(lang)', 0.7860153733374702), ('Kotlin(lang)', 0.31439299860312364), ('yourgodfather12(user)', 0.09989771468624668), ('TopGun666(user)', 0.08532502853816973), ('rxqbi(user)', 0.07856420457280047)]
# Key nodes in Community 13 (sorted by closeness centrality): [('C(lang)', 0.5216942148760331), ('yourgodfather12(user)', 0.4082457558609539), ('ysnbogt(user)', 0.40529695024077045), ('TopGun666(user)', 0.40351578106272473), ('OSU78(user)', 0.4014308426073132)]
# Key nodes in Community 14 (sorted by degree centrality): [('C++(lang)', 0.523138832997988), ('uzairgheewala(user)', 0.04325955734406439), ('arod79sae(user)', 0.04225352112676057), ('grigolin(user)', 0.04124748490945675), ('Mj23978(user)', 0.04024144869215292)]
# Key nodes in Community 14 (sorted by betweenness centrality): [('C++(lang)', 0.9662875155310109), ('grigolin(user)', 0.0740940487793207), ('Mj23978(user)', 0.07173298748034211), ('arod79sae(user)', 0.07115806622210605), ('m-1806(user)', 0.06364514715010444)]
# Key nodes in Community 14 (sorted by closeness centrality): [('C++(lang)', 0.6734417344173442), ('grigolin(user)', 0.41694630872483224), ('arod79sae(user)', 0.41589958158995816), ('Mj23978(user)', 0.41537818637693275), ('m-1806(user)', 0.41537818637693275)]
# Key nodes in Community 15 (sorted by degree centrality): [('C#(lang)', 0.37678207739307534), ('zcensa(user)', 0.049898167006109974), ('coondog024(user)', 0.04684317718940936), ('MattFromRVA(user)', 0.045824847250509164), ('cryptocoinserver(user)', 0.04378818737270875)]
# Key nodes in Community 15 (sorted by betweenness centrality): [('C#(lang)', 0.9461322789879005), ('zcensa(user)', 0.09925896860443532), ('coondog024(user)', 0.07977644491779658), ('misaon(user)', 0.07884587494071978), ('Element21(user)', 0.07777750096365861)]
# Key nodes in Community 15 (sorted by closeness centrality): [('C#(lang)', 0.6080495356037152), ('zcensa(user)', 0.3970885564092196), ('cryptocoinserver(user)', 0.3959677419354839), ('q32854978lhy(user)', 0.39517102615694166), ('Gaserd(user)', 0.39453595821615106)]

# %%
G = g.copy()
def get_user_neighbors(G, user):
    return set(G.neighbors(user))
# calculate Jaccard Similarity
def jaccard_similarity(set1, set2):
    intersection = len(set1 & set2)
    union = len(set1 | set2)
    if union == 0:
        return 0.0
    return intersection / union
def top_jaccard_similarities(G, target_user, top_n=3):
    target_neighbors = get_user_neighbors(G, target_user)
    similarities = []
    
    for node in G.nodes:
        if G.nodes[node].get('type') == 'user' and node != target_user:
            neighbors = get_user_neighbors(G, node)
            similarity = jaccard_similarity(target_neighbors, neighbors)
            similarities.append((node, similarity))

    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[:top_n]
target_user = 'cadekeenan(user)'
top_similar_users = top_jaccard_similarities(G, target_user)

print(f"Top 3 users most similar to {target_user}:")
for user, similarity in top_similar_users:
    print(f"{user}: Jaccard Similarity = {similarity}")
# Out:
# Top 3 users most similar to cadekeenan(user):
# playpicasso(user): Jaccard Similarity = 0.12389380530973451
# yungdz(user): Jaccard Similarity = 0.11494252873563218
# michaelemmanuel16(user): Jaccard Similarity = 0.11392405063291139

# %%
node_mapping = {node: i for i, node in enumerate(G.nodes())}
node_features = []
node_types = []

for node, data in G.nodes(data=True):
    node_types.append(data['type'])
    if data['type'] == 'user':
        node_features.append([1, 0, 0])
    elif data['type'] == 'lang':
        node_features.append([0, 1, 0])
    elif data['type'] == 'repo':
        node_features.append([0, 0, 1])

node_features = torch.tensor(node_features, dtype=torch.float)

edge_index = []
edge_type = []

for u, v, data in G.edges(data=True):
    edge_index.append([node_mapping[u], node_mapping[v]])
    edge_type.append(data['type'])

edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()

# Create Pyg 
data = Data(x=node_features, edge_index=edge_index)

# %%
class GraphSAGE(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GraphSAGE, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, out_channels)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return x
in_channels = data.num_node_features
hidden_channels = 16
out_channels = in_channels  

# Initailize the model
model = GraphSAGE(in_channels, hidden_channels, out_channels)

# Define optimizer 
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.MSELoss()

# Train the model
def train(data, epochs=100):
    model.train()
    for epoch in range(epochs):
        optimizer.zero_grad()
        out = model(data)
        loss = criterion(out, data.x)  # 自监督任务
        loss.backward()
        optimizer.step()
        if epoch % 10 == 0:
            print(f'Epoch {epoch}, Loss: {loss.item()}')

train(data)
model.eval()
with torch.no_grad():
    embeddings = model(data)
print(embeddings)
# Out:
# Epoch 0, Loss: 0.49496185779571533
# Epoch 10, Loss: 0.03259247541427612
# Epoch 20, Loss: 0.012529782019555569
# Epoch 30, Loss: 0.011746331118047237
# Epoch 40, Loss: 0.002692240523174405
# Epoch 50, Loss: 0.0013530156575143337
# Epoch 60, Loss: 0.0009395055822096765
# Epoch 70, Loss: 0.0005343969096429646
# Epoch 80, Loss: 0.00040521862683817744
# Epoch 90, Loss: 0.00036999466829001904
# tensor([[ 4.0501e-02,  1.7501e-02,  9.3501e-01],
#         [ 1.0056e+00, -4.8570e-05, -2.1098e-02],
#         [ 5.5822e-01,  1.0551e-01,  4.9140e-01],
#         ...,
#         [ 1.4984e-03,  9.8198e-01,  3.4729e-03],
#         [ 1.4984e-03,  9.8198e-01,  3.4729e-03],
#         [ 1.4984e-03,  9.8198e-01,  3.4729e-03]])

# %%
def calculate_cosine_similarity(embeddings, node1, node2):
    node1_embedding = embeddings[node1].numpy().reshape(1, -1)
    node2_embedding = embeddings[node2].numpy().reshape(1, -1)
    similarity = cosine_similarity(node1_embedding, node2_embedding)[0][0]
    return similarity

def top_cosine_similarities(embeddings, target_user, top_n=10):
    user_index = node_mapping[target_user]
    user_embedding = embeddings[user_index].numpy().reshape(1, -1)
    repo_indices = [i for i, node in enumerate(G.nodes) if G.nodes[node]['type'] == 'repo']

    similarities = []
    for repo_index in repo_indices:
        repo_embedding = embeddings[repo_index].numpy().reshape(1, -1)
        similarity = cosine_similarity(user_embedding, repo_embedding)[0][0]
        similarities.append((list(G.nodes)[repo_index], similarity))

    similarities.sort(key=lambda x: x[1], reverse=True)
    return similarities[:top_n]

top_similar_nodes = top_cosine_similarities(embeddings, 'michaelemmanuel16(user)')
print(f'Top 10 nodes most similar to node user1:')
for node, similarity in top_similar_nodes:
    print(f'Node {node}: Cosine Similarity = {similarity}')
# Out:
# Cosine similarity between node 0 and node 1: 0.02230467088520527
# Top 10 nodes most similar to node user1:
# Node NBA-Machine-Learning-Sports-Betting(repo): Cosine Similarity = 0.02230467088520527
# Node ChatGPT_Sports_Betting_Bot(repo): Cosine Similarity = 0.02212148904800415
# Node sports-betting(repo): Cosine Similarity = 0.021768363192677498
# Node ProphitBet-Soccer-Bets-Predictor(repo): Cosine Similarity = 0.02039150521159172
# Node Sports-betting(repo): Cosine Similarity = 0.02031581476330757
# Node public-apis(repo): Cosine Similarity = 0.02026885189116001
# Node ollama(repo): Cosine Similarity = 0.020064987242221832
# Node AutoGPT(repo): Cosine Similarity = 0.020042194053530693
# Node WagerBrain(repo): Cosine Similarity = 0.019874680787324905
# Node NBA_Betting(repo): Cosine Similarity = 0.01930730976164341
